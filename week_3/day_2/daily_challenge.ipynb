# %% [markdown]
# # Daily challenge

# %%
import pandas as pd

# %%
raw_data = pd.read_csv("data/global_power_plant_database.csv")
# Out:
# /var/folders/hq/wqwzmqh53mx_hqlw2tl75b9c0000gn/T/ipykernel_7910/3767720930.py:1: DtypeWarning: Columns (0: other_fuel3) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv("data/global_power_plant_database.csv")

# %%
raw_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         34936 non-null  str
#  1   country_long                    34936 non-null  str
#  2   name                            34936 non-null  str
#  3   gppd_idnr                       34936 non-null  str
#  4   capacity_mw                     34936 non-null  float64
#  5   latitude                        34936 non-null  float64
#  6   longitude                       34936 non-null  float64
#  7   primary_fuel                    34936 non-null  str
#  8   other_fuel1                     1944 non-null   str
#  9   other_fuel2                     276 non-null    str
#  10  other_fuel3                     92 non-null     str
#  11  commissioning_year              17447 non-null  float64
# ...

# %%
raw_data.dtypes
# Out:
# country                               str
# country_long                          str
# name                                  str
# gppd_idnr                             str
# capacity_mw                       float64
# latitude                          float64
# longitude                         float64
# primary_fuel                          str
# other_fuel1                           str
# other_fuel2                           str
# other_fuel3                           str
# commissioning_year                float64
# owner                                 str
# source                                str
# url                                   str
# geolocation_source                    str
# wepp_id                               str
# year_of_capacity_data             float64
# generation_gwh_2013               float64
# generation_gwh_2014               float64
# generation_gwh_2015               float64
# generation_gwh_2016               float64
# ...

# %%
raw_data.isnull().sum()
# Out:
# country                               0
# country_long                          0
# name                                  0
# gppd_idnr                             0
# capacity_mw                           0
# latitude                              0
# longitude                             0
# primary_fuel                          0
# other_fuel1                       32992
# other_fuel2                       34660
# other_fuel3                       34844
# commissioning_year                17489
# owner                             14068
# source                               15
# url                                  18
# geolocation_source                  419
# wepp_id                           18702
# year_of_capacity_data             20049
# generation_gwh_2013               28519
# generation_gwh_2014               27710
# generation_gwh_2015               26733
# generation_gwh_2016               25792
# generation_gwh_2017               25436
# ...

# %%
raw_data.memory_usage(deep=True)
# Out:
# Index                                 132
# country                           1816672
# country_long                      2130748
# name                              2354595
# gppd_idnr                         2061888
# capacity_mw                        279488
# latitude                           279488
# longitude                          279488
# primary_fuel                      1871100
# other_fuel1                       1157789
# other_fuel2                       1123736
# other_fuel3                       1119916
# commissioning_year                 279488
# owner                             1964644
# source                            2714956
# url                               3927680
# geolocation_source                2626891
# wepp_id                           1496542
# year_of_capacity_data              279488
# generation_gwh_2013                279488
# generation_gwh_2014                279488
# generation_gwh_2015                279488
# ...

# %%
def inspect_dataframe(df):
    """
    Résumé rapide du dataset
    """

    print("=" * 60)
    print("DATASET OVERVIEW")
    print("=" * 60)

    print(f"\nNombre de lignes : {df.shape[0]}")
    print(f"Nombre de colonnes : {df.shape[1]}")

    print("\nTypes détectés :")
    print(df.dtypes)

    print("\nValeurs manquantes :")
    print(df.isnull().sum())

    print("\nMémoire utilisée :")
    print(
        round(
            df.memory_usage(deep=True).sum() / 1024**2,
            2
        ),
        "MB"
    )

    print("\nAperçu :")
    print(df.head())

# %%
inspect_dataframe(raw_data)
# Out:
# ...
# DATASET OVERVIEW
# ...
#
# Nombre de lignes : 34936
# Nombre de colonnes : 36
#
# Types détectés :
# country                               str
# country_long                          str
# name                                  str
# gppd_idnr                             str
# capacity_mw                       float64
# latitude                          float64
# longitude                         float64
# primary_fuel                          str
# other_fuel1                           str
# other_fuel2                           str
# other_fuel3                           str
# commissioning_year                float64
# owner                                 str
# source                                str
# url                                   str
# geolocation_source                    str
# wepp_id                               str
# year_of_capacity_data             float64
# generation_gwh_2013               float64
# generation_gwh_2014               float64
# ...
